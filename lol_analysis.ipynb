# %% [markdown]
# # LoL Analysis

# %%
import requests

# %%
# Your Riot API key (replace with your actual API key)
API_KEY = 'your_api_key_here'

# Base URL for the Riot API
BASE_URL = 'https://<region>.api.riotgames.com/lol'

# Replace <region> with your region (e.g., na1, euw1, etc.)
REGION = 'oc1'

# Function to get summoner data by summoner name
def get_summoner_data(summoner_name):
    headers = {'X-Riot-Token': API_KEY}
    return
